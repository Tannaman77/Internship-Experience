# %% [markdown]
# # A plotting test
#
# blah blah this is just text, and this is _italic_ **bold**

# %%
from matplotlib import pyplot
import numpy as np

# %%
wave1 = Waveforms[0,:]
T = np.array(range(1,501,1))
T2 = T * (4e-9/500)
ZValues = zip(T2,wave1)
for x,y in ZValues:

# %%
k2 = 2090
Trigger2 = False
Pulse2 = []
XM2 = []
VMin2 = []
waveform = []
Trigger2 = False
for t,v in zip(T2)
    if wave < k2 and Trigger == False:
        Trigger = True
        Pulse2.append(wave)
        
        

        
        
    if wave > k2 and Trigger == True:
        Trigger = False
        xmin2 = min(Pulse2)
# Out:
#   Input In [192]
#     for t,v in zip(T,)
#                       ^
# SyntaxError: invalid syntax

# %%
Pulse2
# Out:
# [2088.0,
#  2088.0,
#  2085.0,
#  2085.0,
#  2087.0,
#  2089.0,
#  2087.0,
#  2088.0,
#  2089.0,
#  2084.0]

# %%
pyplot.figure(1)
pyplot.plot(T,V,lw=2,c='g',ls=':')
pyplot.axhline(y=k,xmin = 0, xmax = 1, c = 'r' )
pyplot.grid()
pyplot.scatter(Pulse,VMin,c='b')
pyplot.xlabel('Time in Micro seconds')
pyplot.ylabel('Voltage')
pyplot.show()

# %%
pyplot.figure(2)
pyplot.plot(wave1,lw = 2, c = 'g', ls = ':')
pyplot.axhline(y=k2,xmin = 0, xmax = 1, c = 'r' )
pyplot.scatter(Pulse2,VMin2,c='b')
pyplot.grid()
pyplot.show()

# %%
pyplot.hist(VMin)
# Out:
# (array([ 1.,  0.,  0.,  0.,  0.,  1.,  0.,  1.,  4., 35.]),
#  array([-0.01785804, -0.01557538, -0.01329271, -0.01101005, -0.00872739,
#         -0.00644472, -0.00416206, -0.0018794 ,  0.00040327,  0.00268593,
#          0.00496859]),
#  <BarContainer object of 10 artists>)
